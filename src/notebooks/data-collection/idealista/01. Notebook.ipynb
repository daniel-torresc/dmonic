# %%
from dotenv import load_dotenv
load_dotenv()

import pandas as pd
import os
import requests
import base64
import json
from datetime import datetime
from pathlib import Path

# %%
def get_project_root() -> Path:
    return Path(os.getcwd()).parent.parent.parent.parent

# %%
def get_oauth_token(key: str, sec: str):
    url = "https://api.idealista.com/oauth/token"

    auth = base64.b64encode(bytes(f'{key}:{sec}', 'utf-8'))

    headers = {
        'Authorization' : f"Basic {auth.decode('utf-8')}",
        'Content-Type': 'application/x-www-form-urlencoded',
    }

    params = {
        'grant_type': 'client_credentials',
        'score': 'read'
    }

    content = requests.post(url, headers=headers, params=params)

    return json.loads(content.text)['access_token']

# %%
def search_api(token: str, page: int):
    url = "https://api.idealista.com/3.5/es/search"

    headers = {
        'Authorization': f"Bearer {token}",
        'Content-Type': 'Content-Type: multipart/form-data'
    }

    params = {
        'numPage': page,
        'operation': 'sale',
        'propertyType': 'homes',
        'maxItems': '50',
        'locationId': '0-EU-ES-29-02-001-067',  # Malaga
        'distance': '6000'
    }

    return json.loads(requests.post(url, headers=headers, params=params).text)

# %%
def persist_data(df_idealista):
    filename = "idealista_data.pickle"

    file_path = os.path.join(get_project_root(), 'data', 'raw', filename)

    try:
        df_prev = pd.read_pickle(file_path)

        pd.concat([df_prev, df_idealista], ignore_index=True).to_pickle(file_path)
    except FileNotFoundError:
        print("No previous data collected.")
        df_idealista.to_pickle(file_path)

# %%
credentials_index = 1
num_page = 1

results = []
while True:
    apikey = os.environ.get(f"IDEALISTA_APIKEY_{credentials_index}")
    secret = os.environ.get(f"IDEALISTA_SECRET_{credentials_index}")

    if any([apikey is None, secret is None]):
        print("No more credentials. Finishing execution...")
        break

    access_token = get_oauth_token(apikey, secret)

    try:
        response = search_api(access_token, num_page)
    except ValueError as e:
        print(f"Can't do more requests with credentials {credentials_index}. Trying with others.")
        credentials_index += 1

        continue

    if 'elementList' in response:
        print(f"Credentials: {credentials_index}\tPage number: {num_page}")

        partial_df = pd.DataFrame.from_dict(response['elementList'])
        partial_df['DATE_RETRIEVED'] = datetime.now()
        results.append(partial_df)

        num_page += 1

        if num_page == response.get('totalPages'):
            print("Finishing execution...")
            break
# Out:
# Page number: 1
# Page number: 2
# Page number: 3
# Page number: 4
# Page number: 5
# Page number: 6
# Page number: 7
# Page number: 8
# Page number: 9
# Page number: 10
# Page number: 11
# Page number: 12
# Page number: 13
# Page number: 14
# Page number: 15
# Page number: 16
# Page number: 17
# Page number: 18
# Page number: 19
# Page number: 20
# Page number: 21
# Page number: 22
# Page number: 23
# Page number: 24
# Page number: 25
# Page number: 26
# Page number: 27
# Page number: 28
# Page number: 29
# Page number: 30
# Page number: 31
# Page number: 32
# Page number: 33
# Page number: 34
# Page number: 35
# Page number: 36
# Page number: 37
# Page number: 38
# Page number: 39
# Page number: 40
# Page number: 41
# Page number: 42
# Page number: 43
# Page number: 44
# Page number: 45
# Page number: 46
# Page number: 47
# Page number: 48
# Page number: 49
# Page number: 50
https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1        98401330  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2        91845863  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3        98082302  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4        96888896  https://img3.idealista.com/blur/WEB_LISTING/0/...
# ...           ...                                                ...
# 4673     98070201                                                NaN
# 4674     98366406                                                NaN
# 4675     98986313                                                NaN
# 4676     96610607                                                NaN
# 4677     97554031                                                NaN
#
#      externalReference  numPhotos floor      price propertyType operation  \
# 0             BS171961       32.0     5  1074000.0         flat      sale
# 1             JR176312       38.0     2   329500.0         flat      sale
# 2             BS151978       29.0     5   850000.0    penthouse      sale
# 3             151703JC       35.0   NaN  2495000.0       chalet      sale
# 4             JR171245       32.0     4  1950000.0       duplex      sale
# ...                ...        ...   ...        ...          ...       ...
# 4673               654        0.0    bj   175000.0       studio      sale
# 4674            222307        0.0     7   135000.0         flat      sale
# 4675     CAN0000189899        0.0   NaN   207400.0         flat      sale
# 4676              3122        0.0     2   110000.0         flat      sale
# 4677            000681        0.0     1   175000.0         flat      sale
#
#        size exterior  ...  hasPlan  has3DTour has360 hasStaging  \
# 0     149.0     True  ...     True       True  False      False
# 1     132.0     True  ...     True       True  False      False
# 2     174.0     True  ...     True       True  False      False
# 3     629.0    False  ...     True       True  False      False
# 4     238.0     True  ...     True       True  False      False
# ...     ...      ...  ...      ...        ...    ...        ...
# 4673   53.0     True  ...    False      False  False      False
# 4674   95.0     True  ...    False      False  False      False
# 4675   71.0    False  ...    False      False  False      False
# 4676   36.0     True  ...    False      False  False      False
# 4677  143.0    False  ...    False      False  False      False
#
#                                                  labels superTopHighlight  \
# 0              [{'name': 'luxuryType', 'text': 'Lujo'}]             False
# 1                                                   NaN             False
# 2              [{'name': 'luxuryType', 'text': 'Lujo'}]             False
# 3     [{'name': 'villaType', 'text': 'Villa'}, {'nam...             False
# 4                                                   NaN             False
# ...                                                 ...               ...
# 4673                                                NaN             False
# 4674                                                NaN             False
# 4675                                                NaN             False
# 4676  [{'name': 'apartamentoType', 'text': 'Apartame...             False
# 4677                                                NaN             False
#
#      topNewDevelopment                                       parkingSpace  \
# 0                False                                                NaN
# 1                False  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 2                False                                                NaN
# 3                False  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 4                False  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# ...                ...                                                ...
# 4673             False                                                NaN
# 4674             False                                                NaN
# 4675             False                                                NaN
# 4676             False                                                NaN
# 4677             False                                                NaN
#
#       newDevelopmentFinished             DATE_RETRIEVED
# 0                        NaN 2022-10-08 17:22:16.562386
# 1                        NaN 2022-10-08 17:22:16.562386
# 2                        NaN 2022-10-08 17:22:16.562386
# 3                        NaN 2022-10-08 17:22:16.562386
# 4                        NaN 2022-10-08 17:22:16.562386
# ...                      ...                        ...
# 4673                     NaN 2022-10-08 17:23:13.061836
# 4674                     NaN 2022-10-08 17:23:13.061836
# 4675                     NaN 2022-10-08 17:23:13.061836
# 4676                     NaN 2022-10-08 17:23:13.061836
# 4677                     NaN 2022-10-08 17:23:13.061836
#
# [4678 rows x 40 columns]
